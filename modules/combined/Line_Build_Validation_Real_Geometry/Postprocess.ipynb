# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
import pandas as pd

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Times'

# %%
fname = 'LENS_database_v1.csv'
lens_data=pd.read_csv(fname,index_col=0)

# %%
lens_data.head()
# Out:
#         Laser,W  LF,ipm  PF,rpm  PF Rate (g/min)  Bead H1  Bead H2  Bead H3  \
# Index#
# 1           200       5       1             1.86       97       97       97
# 2           200      10       1             1.86       47       32       39
# 3           200      15       1             1.86       29       21       25
# 4           200      20       1             1.86       14        9       12
# 5           200       5       2             3.72      166      136      151
#
#         ~Bead Havg  Bead W1  Bead W2  Bead W3  ~Bead Wavg  Width, S  h-max  \
# Index#
# 1            97.00      552      552      552      552.00       501     80
# 2            39.33      508      502      505      505.00       491     39
# 3            25.00      497      495      196      396.00       463     20
# 4            11.67      460      458      459      459.00       438      9
# 5           151.00      527      508      517      517.33       528    138
#
# ...

# %%
lens_data.loc[lens_data.index==40]
# Out:
#         Laser,W  LF,ipm  PF,rpm  PF Rate (g/min)  Bead H1  Bead H2  Bead H3  \
# Index#
# 40          300      25       5              9.3      110      104       98
#
#         ~Bead Havg  Bead W1  Bead W2  Bead W3  ~Bead Wavg  Width, S  h-max  \
# Index#
# 40           104.0      700      725      710      711.67       734     98
#
#           d  A0(bead)  A0(melt)  ~A0(total)  speed mm/s
# Index#
# 40      166     46278     91465      137743       10.58

# %%
fname = 'output/Line_sub_speed_10.58e-3_power_300e-3.csv'
line_print_data=pd.read_csv(fname)

# %%
line_print_data.head()
# Out:
#    time  deposition_length  deposition_volume  max_temperature  \
# 0   0.0            0.00000           0.000000         0.000000
# 1   1.0            0.01058           0.000125         0.000000
# 2   2.0            0.02116           0.000125         0.000000
# 3   3.0            0.03174           0.001510      1469.571211
# 4   4.0            0.04232           0.001510      1469.571211
#
#    max_von_mises_stress  min_temperature  min_von_mises_stress  pp_power  \
# 0              0.000000         0.000000              0.000000       0.0
# 1              0.000161         0.000000              0.000161       0.3
# 2              0.000161         0.000000              0.000161       0.3
# 3              0.000931       587.882547              0.000697       0.3
# 4              0.000931       587.882547              0.000697       0.3
#
#    pp_speed
# 0   0.00000
# 1   0.01058
# 2   0.01058
# 3   0.01058
# 4   0.01058

# %%
line_print_data.count()
# Out:
# time                    380
# deposition_length       380
# deposition_volume       380
# max_temperature         380
# max_von_mises_stress    380
# min_temperature         380
# min_von_mises_stress    380
# pp_power                380
# pp_speed                380
# dtype: int64

# %%
line_print_data.iloc[379]
# Out:
# time                     378.071834
# deposition_length          4.000000
# deposition_volume          0.163328
# max_temperature         1688.906326
# max_von_mises_stress       0.003755
# min_temperature          595.172922
# min_von_mises_stress       0.000784
# pp_power                   0.300000
# pp_speed                   0.010580
# Name: 379, dtype: float64

# %%
line_print_data['deposition_volume'].iloc[379]/line_print_data['deposition_length'].iloc[379]
# Out:
# 40831.893012287495
